# %%
# Tool Setup

# %load_ext tensorboard

import pathlib, os, sys, operator, re, datetime

from functools import reduce
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import Model
import tensorflow_datasets as tfds
import h5py
import pandas as pd

# Use seaborn for pairplot.
# pip install -q seaborn

import seaborn as sns

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %reload_ext tensorboard

print(tf.__version__)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# 2.19.0

# %% [markdown]
# # Importing Season Stast

# %%
data2018 = 'p:\Mitchell\FFNeuralNetwork\stats2018.csv'
data2019 = 'p:\Mitchell\FFNeuralNetwork\stats2019.csv'
data2020 = 'p:\Mitchell\FFNeuralNetwork\stats2020.csv'
data2021 = 'p:\Mitchell\FFNeuralNetwork\stats2021.csv'
data2022 = 'p:\Mitchell\FFNeuralNetwork\stats2022.csv'
data2023 = 'p:\Mitchell\FFNeuralNetwork\stats2023.csv'
data2024 = 'p:\Mitchell\FFNeuralNetwork\stats2024.csv'

rank2018 = pd.read_csv(data2018)
H_2018 = rank2018.shape[0]
finish_2018 = np.array([H_2018])
finish_2018 = rank2018["Column2"]
ppr_2018 = rank2018["Column1"]

rank2019 = pd.read_csv(data2019)
H_2019 = rank2019.shape[0]
PlayerName2019 = np.array([H_2019])
PlayerName2019 = rank2019["Column2"]
ranking2019 = rank2019["Column1"]
age_2019 = rank2019["Column5"]

rank2020 = pd.read_csv(data2020)
H_2020 = rank2020.shape[0]
PlayerName2020 = np.array([H_2020])
PlayerName2020 = rank2020["Column2"]
ranking2020 = rank2020["Column1"]
age_2020 = rank2020["Column5"]

rank2021 = pd.read_csv(data2021)
H_2021 = rank2021.shape[0]
PlayerName2021 = np.array([H_2021])
PlayerName2021 = rank2021["Column2"]
ranking2021 = rank2021["Column1"]
age_2021 = rank2021["Column5"]

rank2022 = pd.read_csv(data2022)
H_2022 = rank2022.shape[0]
PlayerName2022 = np.array([H_2022])
PlayerName2022 = rank2022["Column2"]
ranking2022 = rank2022["Column1"]
age_2022 = rank2022["Column6"]

rank2023 = pd.read_csv(data2023)
H_2023 = rank2023.shape[0]
finish_2023 = np.array([H_2023])
finish_2023 = rank2023["Column2"]
ppr_2023 = rank2023["Column1"]
age_2023 = rank2023["Column5"]

rank2024 = pd.read_csv(data2024)
H_2024 = rank2024.shape[0]
finish_2024 = np.array([H_2024])
finish_2024 = rank2024["Player"]
ppr_2024 = rank2024["Rk"]
age_2024 = rank2024["Age"]

# %%
draftedPlayers = 'p:\Mitchell\FFNeuralNetwork\MattsPlayers.csv'

draft = pd.read_csv(draftedPlayers)
draft_S = draft.shape[0]
players = np.array([draft_S])
players2019 = draft["2019"]
players2020 = draft["2020"]
players2021 = draft["2021"]
players2022 = draft["2022"]
players2023 = draft["2023"]
players2024 = draft["2024"]

print(players2022)
# Out:
# 0       Alvin Kamara
# 1       Travis Kelce
# 2       Keenan Allen
# 3         D.J. Moore
# 4     Justin Herbert
# 5      Dameon Pierce
# 6     Michael Thomas
# 7       Chris Godwin
# 8       Nyheim Hines
# 9      Melvin Gordon
# 10            Colts
# 11    Kadarius Toney
# 12     Treylon Burks
# 13     Jarvis Landry
# 14          Matt Gay
# 15       Alec Pierce
# Name: 2022, dtype: object

# %%
rank_2019 = []
age2019 = []
for h in range(draft_S):
    player2019Name = players2019[h]
    for i in range(2, H_2019):
        player2019 = PlayerName2019[i]
        if(player2019 == player2019Name):
            # rank_2024 = np.append(rank_2024, [i-1])
            rank_2019.append(ranking2019[i])
            age2019.append(age_2019[i])
            break
        if(i == H_2019 -1):
            rank_2019.append(0)
            age2019.append(0)
rank_2019 = np.array(rank_2019)

# print(rank_2019)
# print(age2019)

rank_2020 = []
age2020 = []
for h in range(draft_S):
    player2020Name = players2020[h]
    for i in range(2, H_2020):
        player2020 = PlayerName2020[i]
        if(player2020 == player2020Name):
            # rank_2024 = np.append(rank_2024, [i-1])
            rank_2020.append(ranking2020[i])
            age2020.append(age_2020[i])
            break
        if(i == H_2020 -1):
            rank_2020.append(0)
            age2020.append(0)
rank_2020 = np.array(rank_2020)

print(rank_2020)
print(age2020)

rank_2021 = []
age2021 = []
for h in range(draft_S):
    player2021Name = players2021[h]
    for i in range(2, H_2021):
        player2021 = PlayerName2021[i]
        if(player2021 == player2021Name):
            # rank_2024 = np.append(rank_2024, [i-1])
            rank_2021.append(ranking2021[i])
            age2021.append(age_2021[i])
            break
        if(i == H_2021 -1):
            rank_2021.append(0)
            age2021.append(0)
rank_2021 = np.array(rank_2021)

# print(rank_2021)
# print(age2021)

rank_2022 = []
age2022 = []
for h in range(draft_S):
    player2022Name = players2022[h]
    for i in range(2, H_2022):
        player2022 = PlayerName2022[i]
        if(player2022 == player2022Name):
            # rank_2024 = np.append(rank_2024, [i-1])
            rank_2022.append(ranking2022[i])
            age2022.append(age_2022[i])
            break
        if(i == H_2022 -1):
            rank_2022.append(0)
            age2022.append(0)
rank_2022 = np.array(rank_2022)

# print(rank_2022)
# print(age2022)

rank_2023 = []
age2023 = []
for h in range(draft_S):
    player2023Name = players2023[h]
    for i in range(2, H_2023):
        player2023 = finish_2023[i]
        if(player2023 == player2023Name):
            # rank_2024 = np.append(rank_2024, [i-1])
            rank_2023.append(ppr_2023[i])
            age2023.append(age_2023[i])
            break
        if(i == H_2023 -1):
            rank_2023.append(0)
            age2023.append(0)
rank_2023 = np.array(rank_2023)

# print(rank_2023)
# print(age2023)

rank_2024 = []
age2024 = []
for h in range(draft_S):
    player2024Name = players2024[h]
    for i in range(2, H_2024):
        player2024 = finish_2024[i]
        if(player2024 == player2024Name):
            # rank_2024 = np.append(rank_2024, [i-1])
            rank_2024.append(ppr_2024[i])
            age2024.append(age_2024[i])
            break
        if(i == H_2024 -1):
            rank_2024.append(0)
            age2024.append(0)
rank_2024 = np.array(rank_2024)

# print(rank_2024)
# print(age2024)
# Out:
# ['425' '139' '69' '14' '52' '85' '51' '458' '151' '116' '153' '0' '102'
#  '258' '193' '0']
# ['23', '31', '26', '23', '26', '28', '28', '24', '27', '35', '26', 0, '22', '23', '25', 0]

# %%
update2024 = []
print(update2024)
for h in range(2, H_2023):
    player2023 = finish_2023[h]
    for i in range(2, H_2024):
        player2024 = finish_2024[i]
        if(player2024 == player2023):
            # update2024 = np.append(update2024, [i-1])
            update2024.append(ppr_2024[i])
            break
        if(i == H_2024 -1):
            update2024.append(0)
update2024 = np.array(update2024)

update2023 = []
print(update2023)
for h in range(2, H_2022):
    player2022 = PlayerName2022[h]
    for i in range(2, H_2023):
        player2023 = finish_2023[i]
        if(player2023 == player2022):
            # update2023 = np.append(update2023, [i-1])
            update2023.append(ppr_2023[i])
            break
        if(i == H_2023 -1):
            update2023.append(0)
update2023 = np.array(update2023)

update2022 = []
print(update2022)
for h in range(2, H_2021):
    player2021 = PlayerName2021[h]
    for i in range(2, H_2022):
        player2022 = PlayerName2022[i]
        if(player2022 == player2021):
            # update2022 = np.append(update2022, [i-1])
            update2022.append(rank_2022[i])
            break
        if(i == H_2022 -1):
            update2022.append(0)
update2022 = np.array(update2022)

update2021 = []
print(update2021)
for h in range(2, H_2020):
    player2020 = PlayerName2020[h]
    for i in range(2, H_2021):
        player2021 = PlayerName2021[i]
        if(player2021 == player2020):
            # update2021 = np.append(update2021, [i-1])
            update2021.append(ranking2021[i])
            break
        if(i == H_2021 -1):
            update2021.append(0)
update2021 = np.array(update2021)

update2020 = []
print(update2020)
for h in range(2, H_2019):
    player2019 = PlayerName2019[h]
    for i in range(2, H_2020):
        player2020 = PlayerName2020[i]
        if(player2020 == player2019):
            # update2020 = np.append(update2020, [i-1])
            update2020.append(ranking2021[i])
            break
        if(i == H_2020 -1):
            update2020.append(0)
update2020 = np.array(update2020)
# Out:
# []
# []
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 37
#      34 player2022 = PlayerName2022[i]
#      35 if(player2022 == player2021):
#      36     # update2022 = np.append(update2022, [i-1])
# ---> 37     update2022.append(rank_2022[i])
#      38     break
#      39 if(i == H_2022 -1):
#
# IndexError: index 104 is out of bounds for axis 0 with size 16

# %% [markdown]
# ## Comparing Previous Season Rank to Next Season

# %%
update2024 = np.empty((0,0))
print(update2024)
for h in range(2, H_2024):
    player2024 = finish_2024[h]
    for i in range(2, H_2023):
        player2023 = finish_2023[i]
        if(player2024 == player2023):
            # update2024 = np.append(update2024, [i-1])
            update2024 = np.append(update2024, ppr_2023[i-1])
            break
        if(i == H_2023 -1):
            update2024 = np.append(update2024, [0])

update2023 = np.empty((0,0))
print(update2023)
for h in range(2, H_2023):
    player2023 = finish_2023[h]
    for i in range(2, H_2022):
        player2022 = PlayerName2022[i]
        ppr2022 = rank_2022[i]
        if(player2023 == player2022):
            # update2023 = np.append(update2023, [i-1])
            update2023 = np.append(update2023, rank_2022[i-1])
            break
        if(i == H_2022 -1):
            update2023 = np.append(update2023, [0])

update2022 = np.empty((0,0))
print(update2022)
for h in range(2, H_2022):
    player2022 = PlayerName2022[h]
    for i in range(2, H_2021):
        player2021 = PlayerName2021[i]
        ppr2021 = ranking2021[i]
        if(player2022 == player2021):
            # update2022 = np.append(update2022, [i-1])
            update2022 = np.append(update2022, ranking2021[i-1])
            break
        if(i == H_2021 -1):
            update2022 = np.append(update2022, [0])

update2021 = np.empty((0,0))
print(update2021)
for h in range(2, H_2021):
    player2021 = PlayerName2021[h]
    for i in range(2, H_2020):
        player2020 = PlayerName2020[i]
        ppr2020 = ranking2020[i]
        if(player2021 == player2020):
            # update2021 = np.append(update2021, [i-1])
            update2021 = np.append(update2021, ranking2020[i-1])
            break
        if(i == H_2020 -1):
            update2021 = np.append(update2021, [0])

update2020 = np.empty((0,0))
print(update2020)
for h in range(2, H_2020):
    player2020 = PlayerName2020[h]
    for i in range(2, H_2019):
        player2019 = PlayerName2019[i]
        ppr2019 = ranking2019[i]
        if(player2020 == player2019):
            # update2020 = np.append(update2020, [i-1])
            update2020 = np.append(update2020, ranking2019[i-1])
            break
        if(i == H_2019 -1):
            update2020 = np.append(update2020, [0])

update2019 = np.empty((0,0))
print(update2019)
for h in range(2, H_2019):
    player2019 = PlayerName2019[h]
    for i in range(2, H_2018):
        player2018 = finish_2018[i]
        ppr2018 = ppr_2018[i]
        if(player2019 == player2018):
            # update2019 = np.append(update2019, [i-1])
            update2019 = np.append(update2019, ppr_2018[i-1])
            break
        if(i == H_2018 -1):
            update2019 = np.append(update2019, [0])

# %% [markdown]
# ## Exporting Data to Excel

# %%
# df2023 = pd.DataFrame(update2024)
df2024 = pd.DataFrame(rank_2024)
# df2024 = pd.DataFrame(age2024)
df2024.to_excel('p:\Mitchell\FFNeuralNetwork\statsFrom2024.xlsx', index=False, sheet_name = "2024")
# df2023 = pd.DataFrame(update2023)
df2023 = pd.DataFrame(rank_2023)
# df2023 = pd.DataFrame(age2023)
df2023.to_excel('p:\Mitchell\FFNeuralNetwork\statsFrom2023.xlsx', index=False, sheet_name = "2023")
# df2022 = pd.DataFrame(update2022)
df2022 = pd.DataFrame(rank_2022)
# df2022 = pd.DataFrame(age2022)
df2022.to_excel('p:\Mitchell\FFNeuralNetwork\statsFrom2022.xlsx', index=False, sheet_name = "2022")
# df2021 = pd.DataFrame(update2021)
df2021 = pd.DataFrame(rank_2021)
# df2021 = pd.DataFrame(age2021)
df2021.to_excel('p:\Mitchell\FFNeuralNetwork\statsFrom2021.xlsx', index=False, sheet_name = "2021")
# df2020 = pd.DataFrame(update2020)
df2020 = pd.DataFrame(rank_2020)
# df2020 = pd.DataFrame(age2020)
df2020.to_excel('p:\Mitchell\FFNeuralNetwork\statsFrom2020.xlsx', index=False, sheet_name = "2020")
# df2019 = pd.DataFrame(update2019)
df2019 = pd.DataFrame(rank_2019)
# df2019 = pd.DataFrame(age2019)
df2019.to_excel('p:\Mitchell\FFNeuralNetwork\statsFrom2019.xlsx', index=False, sheet_name = "2019")
